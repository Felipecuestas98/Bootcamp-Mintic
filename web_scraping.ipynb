# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipecuestas98/Bootcamp-Mintic/blob/main/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**WEB Scraping**

# %% [markdown]
# ### El Web Scraping es una técnica utilizada para extraer datos de sitios web de manera automática. Este proceso implica el uso de programas de software que envían solicitudes a páginas web, recuperan su contenido HTML, y extraen la información deseada, la cual puede ser almacenada y analizada posteriormente. Es una herramienta poderosa para recolectar grandes volúmenes de datos no estructurados que se encuentran en la web y transformarlos en datos estructurados para análisis, investigación, y diversas aplicaciones comerciales.

# %%
#Instalación de librerías python necesarias, si es requerido
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
# !pip install certifi
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (2024.8.30)

# %%
#Importar librerías para extracción de datos web
import ssl
import certifi
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Sitio web de la extracción de datos
url         = "https://zonafit.co/"
response    = requests.get(url)
soup        = BeautifulSoup(response.content, 'html.parser')

# %%
#recorre los datos del .parser por el div y la clase card_content para extraer los datos de proveedor, nombre y precio de los suplementos de la pagina de inicio
suplementos = soup.find_all('div',class_="card__content")
#crea una lista con la busqueda
book_list = [suplementos]
book_list
# Out:
# [[<div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a class="full-unstyled-link" href="/collections/optimum-nutrition">Optimum Nutrition
#                 </a>
#   </h3><p class="card__caption">Optimum Nutrition es una marca reconocida de productos deportivos y nutrición deportiva....<span class="icon-wrap"><svg class="icon icon-arrow" fill="none" viewbox="0 0 14 10" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M8.537.808a.5.5 0 0 1 .817-.162l4 4a.5.5 0 0 1 0 .708l-4 4a.5.5 0 1 1-.708-.708L11.793 5.5H1a.5.5 0 0 1 0-1h10.793L8.646 1.354a.5.5 0 0 1-.109-.546" fill="currentColor" fill-rule="evenodd"></path></svg>
#   </span>
#   </p></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a class="full-unstyled-link" href="/collections/optimum-nutrition">Optimum Nutrition<span class="icon-wrap"><svg class="icon icon-arrow" fill="none" viewbox="0 0 14 10" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M8.537.808a.5.5 0 0 1 .817-.162l4 4a.5.5 0 0 1 0 .708l-4 4a.5.5 0 1 1-.708-.708L11.793 5.5H1a.5.5 0 0 1 0-1h10.793L8.646 1.354a.5.5 0 0 1-.109-.546" fill="currentColor" fill-rule="evenodd"></path></svg>
#   </span>
#   </a>
#   </h3></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623191785686 NoMediaStandardBadge-template--18334358175958__featured_collection_QTMTen-8623191785686" class="full-unstyled-link" href="/products/proton-whey-smartmuscle" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623191785686">
#                   Proton Whey Smartmuscle
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_QTMTen-8623191785686">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_QTMTen-8623191785686 Badge-template--18334358175958__featured_collection_QTMTen-8623191785686" class="full-unstyled-link" href="/products/proton-whey-smartmuscle" id="CardLink-template--18334358175958__featured_collection_QTMTen-8623191785686">
#                 Proton Whey Smartmuscle
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Smartmuscle</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $150.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $150.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623200075990 NoMediaStandardBadge-template--18334358175958__featured_collection_QTMTen-8623200075990" class="full-unstyled-link" href="/products/prostar-whey-ultimate-nutrition" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623200075990">
#                   Prostar Whey Ultimate Nutrition
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_QTMTen-8623200075990">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_QTMTen-8623200075990 Badge-template--18334358175958__featured_collection_QTMTen-8623200075990" class="full-unstyled-link" href="/products/prostar-whey-ultimate-nutrition" id="CardLink-template--18334358175958__featured_collection_QTMTen-8623200075990">
#                 Prostar Whey Ultimate Nutrition
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Ultimate Nutrition</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $195.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $195.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623196831958 NoMediaStandardBadge-template--18334358175958__featured_collection_QTMTen-8623196831958" class="full-unstyled-link" href="/products/gold-standard-100-whey-naturally-flavored-optimum-nutrition" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623196831958">
#                   Gold Standard 100% Whey Naturally Flavored Optimum Nutrition
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_QTMTen-8623196831958">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_QTMTen-8623196831958 Badge-template--18334358175958__featured_collection_QTMTen-8623196831958" class="full-unstyled-link" href="/products/gold-standard-100-whey-naturally-flavored-optimum-nutrition" id="CardLink-template--18334358175958__featured_collection_QTMTen-8623196831958">
#                 Gold Standard 100% Whey Naturally Flavored Optimum Nutrition
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Optimum Nutrition</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $215.600
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $215.600
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623200403670 NoMediaStandardBadge-template--18334358175958__featured_collection_QTMTen-8623200403670" class="full-unstyled-link" href="/products/gold-standard-100-whey-optimum-nutrition" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623200403670">
#                   Gold Standard 100% Whey Optimum Nutrition
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_QTMTen-8623200403670">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_QTMTen-8623200403670 Badge-template--18334358175958__featured_collection_QTMTen-8623200403670" class="full-unstyled-link" href="/products/gold-standard-100-whey-optimum-nutrition" id="CardLink-template--18334358175958__featured_collection_QTMTen-8623200403670">
#                 Gold Standard 100% Whey Optimum Nutrition
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Optimum Nutrition</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $169.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $169.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623190868182 NoMediaStandardBadge-template--18334358175958__featured_collection_QTMTen-8623190868182" class="full-unstyled-link" href="/products/be-one-gmn" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623190868182">
#                   Be One GMN
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_QTMTen-8623190868182">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_QTMTen-8623190868182 Badge-template--18334358175958__featured_collection_QTMTen-8623190868182" class="full-unstyled-link" href="/products/be-one-gmn" id="CardLink-template--18334358175958__featured_collection_QTMTen-8623190868182">
#                 Be One GMN
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">GMN</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $149.900
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $149.900
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623192244438 NoMediaStandardBadge-template--18334358175958__featured_collection_QTMTen-8623192244438" class="full-unstyled-link" href="/products/la-wey-fitmafia" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623192244438">
#                   La Wey Fitmafia
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_QTMTen-8623192244438">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_QTMTen-8623192244438 Badge-template--18334358175958__featured_collection_QTMTen-8623192244438" class="full-unstyled-link" href="/products/la-wey-fitmafia" id="CardLink-template--18334358175958__featured_collection_QTMTen-8623192244438">
#                 La Wey Fitmafia
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Proscience</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $24.900
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $24.900
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623196537046 NoMediaStandardBadge-template--18334358175958__featured_collection_QTMTen-8623196537046" class="full-unstyled-link" href="/products/isopure-zero-low-carb-isopure-company" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623196537046">
#                   Isopure Zero - Low Carb Isopure Company
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_QTMTen-8623196537046">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_QTMTen-8623196537046 Badge-template--18334358175958__featured_collection_QTMTen-8623196537046" class="full-unstyled-link" href="/products/isopure-zero-low-carb-isopure-company" id="CardLink-template--18334358175958__featured_collection_QTMTen-8623196537046">
#                 Isopure Zero - Low Carb Isopure Company
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Isopure Company</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $125.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $125.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623199944918 NoMediaStandardBadge-template--18334358175958__featured_collection_QTMTen-8623199944918" class="full-unstyled-link" href="/products/iso-sensation-93-ultimate-nutrition" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_QTMTen-8623199944918">
#                   ISO Sensation 93
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_QTMTen-8623199944918">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_QTMTen-8623199944918 Badge-template--18334358175958__featured_collection_QTMTen-8623199944918" class="full-unstyled-link" href="/products/iso-sensation-93-ultimate-nutrition" id="CardLink-template--18334358175958__featured_collection_QTMTen-8623199944918">
#                 ISO Sensation 93
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Ultimate Nutrition</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $209.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $209.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection-8702420123862 NoMediaStandardBadge-template--18334358175958__featured_collection-8702420123862" class="full-unstyled-link" href="/products/burner-stack-360-gr-protein-pancake-1-69-lb" id="StandardCardNoMediaLink-template--18334358175958__featured_collection-8702420123862">
#                   Burner Stack 360 gr + Protein Pancake 1.69 lb
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"><span class="badge badge--bottom-left color-scheme-4" id="NoMediaStandardBadge-template--18334358175958__featured_collection-8702420123862">Oferta</span></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection-8702420123862">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection-8702420123862 Badge-template--18334358175958__featured_collection-8702420123862" class="full-unstyled-link" href="/products/burner-stack-360-gr-protein-pancake-1-69-lb" id="CardLink-template--18334358175958__featured_collection-8702420123862">
#                 Burner Stack 360 gr + Protein Pancake 1.69 lb
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Zona FIT</div><span class="caption-large light"></span>
#   <div class="price price--on-sale">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $165.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#
#                   $202.880
#
#               </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $165.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"><span class="badge badge--bottom-left color-scheme-4" id="Badge-template--18334358175958__featured_collection-8702420123862">Oferta</span></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709569380566 NoMediaStandardBadge-template--18334358175958__featured_collection-8709569380566" class="full-unstyled-link" href="/products/gold-standard-5-lb-amino-x-30-serv" id="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709569380566">
#                   Gold Standard 5 lb + Amino X 30 serv
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection-8709569380566">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection-8709569380566 Badge-template--18334358175958__featured_collection-8709569380566" class="full-unstyled-link" href="/products/gold-standard-5-lb-amino-x-30-serv" id="CardLink-template--18334358175958__featured_collection-8709569380566">
#                 Gold Standard 5 lb + Amino X 30 serv
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Zona FIT</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $400.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $400.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709598118102 NoMediaStandardBadge-template--18334358175958__featured_collection-8709598118102" class="full-unstyled-link" href="/products/gold-standard-100-isolate-5-lb-creatine-legend-30-serv" id="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709598118102">
#                   Gold Standard 100% Isolate 5 lb + Creatine Legend 30 serv
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection-8709598118102">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection-8709598118102 Badge-template--18334358175958__featured_collection-8709598118102" class="full-unstyled-link" href="/products/gold-standard-100-isolate-5-lb-creatine-legend-30-serv" id="CardLink-template--18334358175958__featured_collection-8709598118102">
#                 Gold Standard 100% Isolate 5 lb + Creatine Legend 30 serv
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Zona FIT</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $400.800
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $400.800
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709663031510 NoMediaStandardBadge-template--18334358175958__featured_collection-8709663031510" class="full-unstyled-link" href="/products/gold-standard-5-lb-creatine-healthy-300-gr" id="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709663031510">
#                   Gold Standard 5 lb + Creatine Healthy 300 gr
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection-8709663031510">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection-8709663031510 Badge-template--18334358175958__featured_collection-8709663031510" class="full-unstyled-link" href="/products/gold-standard-5-lb-creatine-healthy-300-gr" id="CardLink-template--18334358175958__featured_collection-8709663031510">
#                 Gold Standard 5 lb + Creatine Healthy 300 gr
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Zona FIT</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $400.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $400.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709666406614 NoMediaStandardBadge-template--18334358175958__featured_collection-8709666406614" class="full-unstyled-link" href="/products/gold-standard-isolate-5-lb-creatine-optimum-300-gr" id="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709666406614">
#                   Gold Standard Isolate 5 lb + Creatine Iron 500 gr
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection-8709666406614">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection-8709666406614 Badge-template--18334358175958__featured_collection-8709666406614" class="full-unstyled-link" href="/products/gold-standard-isolate-5-lb-creatine-optimum-300-gr" id="CardLink-template--18334358175958__featured_collection-8709666406614">
#                 Gold Standard Isolate 5 lb + Creatine Iron 500 gr
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Zona FIT</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $440.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $440.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709961187542 NoMediaStandardBadge-template--18334358175958__featured_collection-8709961187542" class="full-unstyled-link" href="/products/3-unid-gold-standard-100-whey-creatina-optimum-300-gr" id="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709961187542">
#                   3 Unid. Gold Standard 100% Whey + Creatine Iron 500 gr
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection-8709961187542">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection-8709961187542 Badge-template--18334358175958__featured_collection-8709961187542" class="full-unstyled-link" href="/products/3-unid-gold-standard-100-whey-creatina-optimum-300-gr" id="CardLink-template--18334358175958__featured_collection-8709961187542">
#                 3 Unid. Gold Standard 100% Whey + Creatine Iron 500 gr
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Zona FIT</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $393.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $393.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709994152150 NoMediaStandardBadge-template--18334358175958__featured_collection-8709994152150" class="full-unstyled-link" href="/products/gold-standard-100-whey-5-lb-creatine-legend-30-serv" id="StandardCardNoMediaLink-template--18334358175958__featured_collection-8709994152150">
#                   Gold Standard 100% Whey 5 lb + Creatine Legend 30 serv
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection-8709994152150">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection-8709994152150 Badge-template--18334358175958__featured_collection-8709994152150" class="full-unstyled-link" href="/products/gold-standard-100-whey-5-lb-creatine-legend-30-serv" id="CardLink-template--18334358175958__featured_collection-8709994152150">
#                 Gold Standard 100% Whey 5 lb + Creatine Legend 30 serv
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Zona FIT</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $360.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $360.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection-8710077251798 NoMediaStandardBadge-template--18334358175958__featured_collection-8710077251798" class="full-unstyled-link" href="/products/3-unid-gold-standard-100-whey" id="StandardCardNoMediaLink-template--18334358175958__featured_collection-8710077251798">
#                   3 Unid. Gold Standard 100% Whey
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection-8710077251798">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection-8710077251798 Badge-template--18334358175958__featured_collection-8710077251798" class="full-unstyled-link" href="/products/3-unid-gold-standard-100-whey" id="CardLink-template--18334358175958__featured_collection-8710077251798">
#                 3 Unid. Gold Standard 100% Whey
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Zona FIT</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $305.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $305.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_tkcfFj-8751380758742 NoMediaStandardBadge-template--18334358175958__featured_collection_tkcfFj-8751380758742" class="full-unstyled-link" href="/products/amino-energy-electrolytes-sparkling-optimum-nutrition" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_tkcfFj-8751380758742">
#                   Amino Energy + Electrolytes Sparkling Optimum Nutrition
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_tkcfFj-8751380758742">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_tkcfFj-8751380758742 Badge-template--18334358175958__featured_collection_tkcfFj-8751380758742" class="full-unstyled-link" href="/products/amino-energy-electrolytes-sparkling-optimum-nutrition" id="CardLink-template--18334358175958__featured_collection_tkcfFj-8751380758742">
#                 Amino Energy + Electrolytes Sparkling Optimum Nutrition
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Optimum Nutrition</div><span class="caption-large light"></span>
#   <div class="price">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $14.000
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#   </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $14.000
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_tkcfFj-8751594111190 NoMediaStandardBadge-template--18334358175958__featured_collection_tkcfFj-8751594111190" class="full-unstyled-link" href="/products/creatine-chews-muscletech" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_tkcfFj-8751594111190">
#                   Creatine Chews Muscletech
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"><span class="badge badge--bottom-left color-scheme-4" id="NoMediaStandardBadge-template--18334358175958__featured_collection_tkcfFj-8751594111190">Oferta</span></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_tkcfFj-8751594111190">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_tkcfFj-8751594111190 Badge-template--18334358175958__featured_collection_tkcfFj-8751594111190" class="full-unstyled-link" href="/products/creatine-chews-muscletech" id="CardLink-template--18334358175958__featured_collection_tkcfFj-8751594111190">
#                 Creatine Chews Muscletech
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Muscletech</div><span class="caption-large light"></span>
#   <div class="price price--on-sale">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $147.250
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#
#                   $155.000
#
#               </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $147.250
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"><span class="badge badge--bottom-left color-scheme-4" id="Badge-template--18334358175958__featured_collection_tkcfFj-8751594111190">Oferta</span></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_tkcfFj-8748185616598 NoMediaStandardBadge-template--18334358175958__featured_collection_tkcfFj-8748185616598" class="full-unstyled-link" href="/products/gold-standard-protein-shake-optimum-nutrition" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_tkcfFj-8748185616598">
#                   Gold Standard Protein Shake Optimum Nutrition
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"><span class="badge badge--bottom-left color-scheme-4" id="NoMediaStandardBadge-template--18334358175958__featured_collection_tkcfFj-8748185616598">Oferta</span></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_tkcfFj-8748185616598">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_tkcfFj-8748185616598 Badge-template--18334358175958__featured_collection_tkcfFj-8748185616598" class="full-unstyled-link" href="/products/gold-standard-protein-shake-optimum-nutrition" id="CardLink-template--18334358175958__featured_collection_tkcfFj-8748185616598">
#                 Gold Standard Protein Shake Optimum Nutrition
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Optimum Nutrition</div><span class="caption-large light"></span>
#   <div class="price price--on-sale">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               A partir de $8.100
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#
#                   $13.500
#
#               </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             A partir de $8.100
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"><span class="badge badge--bottom-left color-scheme-4" id="Badge-template--18334358175958__featured_collection_tkcfFj-8748185616598">Oferta</span></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading">
#   <a aria-labelledby="StandardCardNoMediaLink-template--18334358175958__featured_collection_tkcfFj-8748287852758 NoMediaStandardBadge-template--18334358175958__featured_collection_tkcfFj-8748287852758" class="full-unstyled-link" href="/products/war-games-redcon1" id="StandardCardNoMediaLink-template--18334358175958__featured_collection_tkcfFj-8748287852758">
#                   War Games Redcon1
#                 </a>
#   </h3>
#   </div>
#   <div class="card__badge bottom left"><span class="badge badge--bottom-left color-scheme-4" id="NoMediaStandardBadge-template--18334358175958__featured_collection_tkcfFj-8748287852758">Oferta</span></div>
#   </div>,
#   <div class="card__content">
#   <div class="card__information">
#   <h3 class="card__heading h5" id="title-template--18334358175958__featured_collection_tkcfFj-8748287852758">
#   <a aria-labelledby="CardLink-template--18334358175958__featured_collection_tkcfFj-8748287852758 Badge-template--18334358175958__featured_collection_tkcfFj-8748287852758" class="full-unstyled-link" href="/products/war-games-redcon1" id="CardLink-template--18334358175958__featured_collection_tkcfFj-8748287852758">
#                 War Games Redcon1
#               </a>
#   </h3>
#   <div class="card-information"><span class="visually-hidden">Proveedor:</span>
#   <div class="caption-with-letter-spacing light">Redcon1</div><span class="caption-large light"></span>
#   <div class="price price--on-sale">
#   <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span class="price-item price-item--regular">
#               $71.200
#             </span></div>
#   <div class="price__sale">
#   <span class="visually-hidden visually-hidden--inline">Precio habitual</span>
#   <span>
#   <s class="price-item price-item--regular">
#
#                   $89.000
#
#               </s>
#   </span><span class="visually-hidden visually-hidden--inline">Precio de oferta</span>
#   <span class="price-item price-item--sale price-item--last">
#             $71.200
#           </span>
#   </div>
#   <small class="unit-price caption hidden">
#   <span class="visually-hidden">Precio unitario</span>
#   <span class="price-item price-item--last">
#   <span></span>
#   <span aria-hidden="true">/</span>
#   <span class="visually-hidden"> por </span>
#   <span>
#   </span>
#   </span>
#   </small>
#   </div></div>
#   </div>
#   </div>
#   <div class="card__badge bottom left"><span class="badge badge--bottom-left color-scheme-4" id="Badge-template--18334358175958__featured_collection_tkcfFj-8748287852758">Oferta</span></div>
#   </div>]]

# %%
# prompt: Con base en el anterior script que es el patron de extraccion de los datos genera un recorrido por las paginas del sitio web para alimentar un dataframe con todos los datos.

import ssl
import certifi
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Install necessary libraries if not already installed
# !pip install requests beautifulsoup4 pandas certifi

def scrape_page(url):
    """Scrapes a single page and returns a list of dictionaries containing product information."""

    try:
        response = requests.get(url, verify=True)
        response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)
        soup = BeautifulSoup(response.content, 'html.parser')
        suplementos = soup.find_all('div', class_="card__content")

        products = []
        for suplemento in suplementos:
            product = {}

            try:
                product['Proveedor'] = suplemento.find('div', class_="caption-with-letter-spacing light").text.strip()
            except AttributeError:
                product['Proveedor'] = "N/A"

            try:
                product['Nombre del Artículo'] = suplemento.find('a', class_="full-unstyled-link").text.strip()
            except AttributeError:
                product['Nombre del Artículo'] = "N/A"

            try:
                product['Precio'] = suplemento.find('span', class_="price-item price-item--regular").text.strip()
            except AttributeError:
                product['Precio'] = "N/A"

            products.append(product)
        return products

    except requests.exceptions.RequestException as e:
        print(f"Error scraping {url}: {e}")
        return []

# Start with the initial URL
base_url = "https://zonafit.co/"
all_products = []


# Implement Pagination Logic (replace with your actual pagination logic)
# This example assumes that each page has a "next page" link
current_page_url = base_url
while True: # loop until there is no next page link
    products = scrape_page(current_page_url)
    if not products: #check that the page was successfully scrapped
        break; # Stop the loop if the scraping fails
    all_products.extend(products)

    #Find the next page link (replace with your specific pagination structure)
    response = requests.get(current_page_url, verify=True)
    soup = BeautifulSoup(response.content, 'html.parser')
    next_page_link = soup.find('a', class_="next") #Replace with the actual class name for the next page link

    if next_page_link:
        current_page_url = next_page_link.get('href')
        if current_page_url.startswith('/'):
          current_page_url = base_url + current_page_url[1:] #Handle relative URLs
    else:
      break


# Create the DataFrame after scraping all pages
df = pd.DataFrame(all_products)
df
# Out:
#              Proveedor                                Nombre del Artículo  \
# 0                  N/A                                  Optimum Nutrition
# 1                  N/A                                  Optimum Nutrition
# 2                  N/A                            Proton Whey Smartmuscle
# 3          Smartmuscle                            Proton Whey Smartmuscle
# 4                  N/A                    Prostar Whey Ultimate Nutrition
# 5   Ultimate Nutrition                    Prostar Whey Ultimate Nutrition
# 6                  N/A  Gold Standard 100% Whey Naturally Flavored Opt...
# 7    Optimum Nutrition  Gold Standard 100% Whey Naturally Flavored Opt...
# 8                  N/A          Gold Standard 100% Whey Optimum Nutrition
# 9    Optimum Nutrition          Gold Standard 100% Whey Optimum Nutrition
# 10                 N/A                                         Be One GMN
# 11                 GMN                                         Be One GMN
# 12                 N/A                                    La Wey Fitmafia
# 13          Proscience                                    La Wey Fitmafia
# 14                 N/A            Isopure Zero - Low Carb Isopure Company
# 15     Isopure Company            Isopure Zero - Low Carb Isopure Company
# 16                 N/A                                   ISO Sensation 93
# 17  Ultimate Nutrition                                   ISO Sensation 93
# 18                 N/A      Burner Stack 360 gr + Protein Pancake 1.69 lb
# 19            Zona FIT      Burner Stack 360 gr + Protein Pancake 1.69 lb
# 20                 N/A               Gold Standard 5 lb + Amino X 30 serv
# 21            Zona FIT               Gold Standard 5 lb + Amino X 30 serv
# 22                 N/A  Gold Standard 100% Isolate 5 lb + Creatine Leg...
# 23            Zona FIT  Gold Standard 100% Isolate 5 lb + Creatine Leg...
# 24                 N/A       Gold Standard 5 lb + Creatine Healthy 300 gr
# 25            Zona FIT       Gold Standard 5 lb + Creatine Healthy 300 gr
# 26                 N/A  Gold Standard Isolate 5 lb + Creatine Iron 500 gr
# 27            Zona FIT  Gold Standard Isolate 5 lb + Creatine Iron 500 gr
# 28                 N/A  3 Unid. Gold Standard 100% Whey + Creatine Iro...
# 29            Zona FIT  3 Unid. Gold Standard 100% Whey + Creatine Iro...
# 30                 N/A  Gold Standard 100% Whey 5 lb + Creatine Legend...
# 31            Zona FIT  Gold Standard 100% Whey 5 lb + Creatine Legend...
# 32                 N/A                    3 Unid. Gold Standard 100% Whey
# 33            Zona FIT                    3 Unid. Gold Standard 100% Whey
# 34                 N/A  Amino Energy + Electrolytes Sparkling Optimum ...
# 35   Optimum Nutrition  Amino Energy + Electrolytes Sparkling Optimum ...
# 36                 N/A                          Creatine Chews Muscletech
# 37          Muscletech                          Creatine Chews Muscletech
# 38                 N/A      Gold Standard Protein Shake Optimum Nutrition
# 39   Optimum Nutrition      Gold Standard Protein Shake Optimum Nutrition
# 40                 N/A                                  War Games Redcon1
# 41             Redcon1                                  War Games Redcon1
#
#                   Precio
# 0                    N/A
# 1                    N/A
# 2                    N/A
# 3   A partir de $150.000
# 4                    N/A
# 5   A partir de $195.000
# 6                    N/A
# 7   A partir de $215.600
# 8                    N/A
# 9   A partir de $169.000
# 10                   N/A
# 11  A partir de $149.900
# 12                   N/A
# 13   A partir de $24.900
# 14                   N/A
# 15  A partir de $125.000
# 16                   N/A
# 17  A partir de $209.000
# 18                   N/A
# 19              $165.000
# 20                   N/A
# 21              $400.000
# 22                   N/A
# 23  A partir de $400.800
# 24                   N/A
# 25              $400.000
# 26                   N/A
# 27              $440.000
# 28                   N/A
# 29              $393.000
# 30                   N/A
# 31  A partir de $360.000
# 32                   N/A
# 33              $305.000
# 34                   N/A
# 35               $14.000
# 36                   N/A
# 37              $147.250
# 38                   N/A
# 39    A partir de $8.100
# 40                   N/A
# 41               $71.200

# %%
# Eliminar filas con datos N/A para tener solo las filas con datos para analizar
df = df[df['Precio'] != 'N/A']
df
# Out:
#              Proveedor                                Nombre del Artículo  \
# 3          Smartmuscle                            Proton Whey Smartmuscle
# 5   Ultimate Nutrition                    Prostar Whey Ultimate Nutrition
# 7    Optimum Nutrition  Gold Standard 100% Whey Naturally Flavored Opt...
# 9    Optimum Nutrition          Gold Standard 100% Whey Optimum Nutrition
# 11                 GMN                                         Be One GMN
# 13          Proscience                                    La Wey Fitmafia
# 15     Isopure Company            Isopure Zero - Low Carb Isopure Company
# 17  Ultimate Nutrition                                   ISO Sensation 93
# 19            Zona FIT      Burner Stack 360 gr + Protein Pancake 1.69 lb
# 21            Zona FIT               Gold Standard 5 lb + Amino X 30 serv
# 23            Zona FIT  Gold Standard 100% Isolate 5 lb + Creatine Leg...
# 25            Zona FIT       Gold Standard 5 lb + Creatine Healthy 300 gr
# 27            Zona FIT  Gold Standard Isolate 5 lb + Creatine Iron 500 gr
# 29            Zona FIT  3 Unid. Gold Standard 100% Whey + Creatine Iro...
# 31            Zona FIT  Gold Standard 100% Whey 5 lb + Creatine Legend...
# 33            Zona FIT                    3 Unid. Gold Standard 100% Whey
# 35   Optimum Nutrition  Amino Energy + Electrolytes Sparkling Optimum ...
# 37          Muscletech                          Creatine Chews Muscletech
# 39   Optimum Nutrition      Gold Standard Protein Shake Optimum Nutrition
# 41             Redcon1                                  War Games Redcon1
#
#                   Precio
# 3   A partir de $150.000
# 5   A partir de $195.000
# 7   A partir de $215.600
# 9   A partir de $169.000
# 11  A partir de $149.900
# 13   A partir de $24.900
# 15  A partir de $125.000
# 17  A partir de $209.000
# 19              $165.000
# 21              $400.000
# 23  A partir de $400.800
# 25              $400.000
# 27              $440.000
# 29              $393.000
# 31  A partir de $360.000
# 33              $305.000
# 35               $14.000
# 37              $147.250
# 39    A partir de $8.100
# 41               $71.200

# %% [markdown]
# # Otros ejemplos de páginas para hacer web scraping

# %%
url = 'https://zonafit.co/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
headlines = soup.find_all(class_='ssrcss-1mhwnz8-Promo e1vyq2e80')
news_list = [headline.get_text() for headline in headlines]
print(news_list)

# %%
news_df = pd.DataFrame(news_list, columns=['Headline'])
news_df.head()
